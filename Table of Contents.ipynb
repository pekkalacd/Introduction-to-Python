# %% [markdown]
# <br>

# %% [markdown]
# # Table of Contents

# %% [markdown]
# **1. Basic Overview**
# - What can we do with computers?
# - What is programming?
# - What is Python?
# - How do I get Python?
# - Why Python?

# %% [markdown]
# **2. Interpreter vs Compiler**
# - Weak Typing vs Strong Typing
# - Process of File to Executable in Compiler
# - Process of File to Executable in Interpreter
# - From C to Python

# %% [markdown]
# **3. Basic Syntax & Your First Program**
# - Comments
# - Doc-strings
# - Indentation
# - Variable Assignment
# - String Syntax
# - Jello World!

# %% [markdown]
# **4. Variables**
# - what is a variable?
# - do we "declare" variables in Python?
# - example usage

# %% [markdown]
# **5. Mutability/ Basic Data Types / Casting**
# - what is mutability?
# - everything in python is an object.
# - str
# - int
# - float
# - bool
# - list
# - dict
# - set
# - tuple
# - range
# - how to change from one data-type to another (casting)
# - can all data-types change?
# - which are mutable and which are immutable

# %% [markdown]
# **6. Basic Operators**
# - basic arithmetic
# - basic logical
# - basic comparison

# %% [markdown]
# **7. More operators**
# - combined assignment operators: *=, %=, +=, -=, //=, /=, **=
# - bitwise: &, |, ^, ~, <<, >>
# - identity: is, is not
# - membership: in, not in

# %% [markdown]
# **8. If/elif/else**
# - If, elif, else differences
# - If
# - If / else
# - If / elif
# - If / elif / else
# - Ternary expressions

# %% [markdown]
# **9. Basic Data Structures**
# - List
# - Tuples
# - Sets
# - Dictionaries

# %% [markdown]
# **10. Strings & Formatting Them**
# - array of characters?
# - immutable
# - "%s" %obj c-style technique
# - f-string technique
# - .format() technique

# %% [markdown]
# **11. Loops**
# - Why use loops?
# - For Loops
# - While Loops
# - Infinite Loops
# - continue
# - break
# - range()
# - range-based loops
# - "iterables"
# - counter-controlled repetition

# %% [markdown]
# **12. Functions Overview**
# - What is a function?
# - Procedural Programming
# - Why use a function?
# - Return statements
# - None-value returning functions & None Type
# - Calling Functions

# %% [markdown]
# **13. Built-in Functions**
# ![image.png](attachment:image.png)

# %% [markdown]
# **14. Scope & Functions**
# - What is Scope?
# - Global vs Local
# - Why does it matter?
# - Nested statements
# - Returning Values

# %% [markdown]
# **15. Multiple Functions & Parameters**
# - Required Parameters
# - Optional Parameters
# - Passing Parameters
# - Tying the program together with functions
# - Globals & Locals together

# %% [markdown]
# **16. File I/O**
# - Open / Close
# - Read / Write
# - Create / Delete
# - Parse Text Files
# - Parse CSV Files
# - Files & Functions
# - Example Program

# %% [markdown]
# **17. Exception Handling & Exception Objects**
# - Errors vs Exceptions
# - Why use Exceptions?
# - Try / Except
# - Try / Except / Finally
# - Exception Objects

# %% [markdown]
# **18. Object Oriented Programming Overview**
# - Procedural vs OOP
# - Animal Kingdom Tree Example
# - What is a class?
# - What is an instance?
# - Attributes / Methods
# - "self"

# %% [markdown]
# **19. Classes**
# - public attributes
# - constructor
# - methods
# - example: Bird class

# %% [markdown]
# **20. Inheritance**
# - Why use inheritance?
# - Back to Zoology
# - super(), className.__init__(self,..)
# - constructor
# - methods
# - Python's Type Class: all objects inherit from this

# %% [markdown]
# **20. Multiple Inheritance**
# - Inheriting from multiple parent classes
# - Method Resolution Order
# - Common Issues with Multiple Inheritance

# %% [markdown]
# **21. Python Data Model & Dunder "Magic" Methods**
# - Understanding the Data Model
# - __init__(), __repr__(), __call__(), __add__(), __sub__(), __prod__()

# %% [markdown]
# **22. Static Methods**
# - What are static methods?
# - Why use static methods?
# - Examples of static methods

# %% [markdown]
# **23. Meta-Classes**
# - What is a meta-class?
# - What does a meta-class do?
# - Python's Type meta-class
# - Creating meta-classes
# - Changing meta-classes

# %% [markdown]
# **24. Managed Attributes**
# - {research more into this...}

# %% [markdown]
# **25. Packages / Libraries / Modules**
# - What is a module?
# - What is a package?
# - What is a library?
# - What is the hierarchy of all 3?
# - Why do we care?
# - How can you use these features?

# %% [markdown]
# **26. pip & pyPI**
# - what is python package index (pyPI) and how do you access it?
# - installing and using pip (windows)
# - what is a .whl file and what does this mean?

# %% [markdown]
# **27. Working with Multiple Python Files**
# - importing files
# - utilizing functions / classes within files to build upon
# - example usages

# %% [markdown]
# **28. Using Libraries**
# - import ns vs from ns import m
# - random library examples
# - numpy library examples
# - math library examples
# - pandas library examples
# - beautifulsoup library examples

# %% [markdown]
# **29. Documentation tools**
# - help() function
# - inspect library
# - great resources: realPython, docs.python.org

# %% [markdown]
# **30. Interpreting Documentation / Common Conventions**
# - What's odd with documentation sometimes?
# - Common conventions
# - Combining tools
# - Tips & Techniques

# %% [markdown]
# **32. Dictionaries / Maps / Hash Tables**
# - What is a Dictionary?
# - What is a Map?
# - What is a Hash Table?
# - Collections library
# - dict
# - Ordered Dictionary
# - Default Dictionary
# - Chain Map

# %% [markdown]
# **33. Arrays & Array-like Structures**
# - What is an Array?
# - What is a List?
# - What is a Tuple?
# - list
# - tuple
# - array.array
# - numpy array
# - str
# - bytes
# - bytearray

# %% [markdown]
# **34. Structs & Data Transfer Objects**
# - What is a named tuple?
# - How does Python handle Structs?
# - dict
# - tuple
# - named tuples
# - Serialized C structs
# - SimpleNamespace

# %% [markdown]
# **35. Sets & Multisets**
# - What is a set?
# - What is a multiset?
# - set()
# - frozenset
# - collections.Counter

# %% [markdown]
# **36. Stacks**
# - What is a Stack in Python?
# - LIFO
# - list
# - collections.deque
# - queue.LifoQueue

# %% [markdown]
# **37. Queues**
# - What is a Queue in Python?
# - FIFO
# - list
# - collections.deque
# - queue.Queue
# - multiprocessing.Queue

# %% [markdown]
# **38. Priority Queues**
# - What is a Priority Queue in Python?
# - list
# - heapq
# - queue.PriorityQueue

# %% [markdown]
# **39. Decorators**
# - What is a Decorator?
# - Why use Decorators?
# - Examples
# - {more research..}

# %% [markdown]
# **40. Iterators & Generators & List Comprehension**
# - What is an iterator?
# - What is a generator?
# - What is List Comprehension?
# - 1-line for-loop
# - Yield vs Return
# - iter()
# - next()

# %% [markdown]
# **41. Lamdba Functions**
# - What are lambda functions?
# - How to use
# - Examples

# %% [markdown]
# **42. Unicode & Byte Strings**
# - Unicode & Byte handling in Python
# - bin(), ord(), ascii(), chr()

# %% [markdown]
# **43. Bytes Objects**
# -  bytes()
# - byte array
# - {more research.....}

# %% [markdown]
# **44. Regular Expressions (RegEx)**
# - What are regular expressions?
# - Why use regular expressions?
# - Syntax
# - Pattern Matching Examples
# - Parsing strings using RegEx
# - Parsing Files using RegEx
# - Web Scraping with RegEx & BeautifulSoup

# %% [markdown]
# **45. JSON**
# - Parsing Json with json library

# %% [markdown]
# **Exercises**
